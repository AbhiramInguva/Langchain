# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Load API keys from the .env file in the root folder
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
print(os.environ["OPENAI_API_KEY"][:20])
# Out:
# sk-proj-UPvTlzpJZvtG

# %%
from openai import models
from langchain.chat_models import init_chat_model
#init chat model used to initalize any chat model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x112625d10>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x112626210>, root_client=<openai.OpenAI object at 0x1126256d0>, root_async_client=<openai.AsyncOpenAI object at 0x112625f90>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('*******
# ...

# %%
responces = model.invoke("Hello how are you?")
responces
# Out:
# AIMessage(content="Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 40, 'total_tokens': 88, 'completion_time': 0.116521825, 'completion_tokens_details': None, 'prompt_time': 0.004721362, 'prompt_tokens_details': None, 'queue_time': 0.055541652, 'total_time': 0.121243187}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e4e32-8f53-7ce3-8ed5-30d393775f5b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 48, 'total_tokens': 88})

# %%
responces.content
# Out:
# "Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?"

# %%
#c hatopenai
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model = "gpt-4.1")
responces = model.invoke("why do parrots talk?")
responces
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 #c hatopenai
#       2 from langchain_openai import ChatOpenAI
#       3 model = ChatOpenAI(model = "gpt-4.1")
# ----> 4 responces = model.invoke("why do parrots talk?")
#       5 responces
#
# File ~/Code/PYTHON/agentic/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
# ...

# %% [markdown]
# ### google gemini model

# %%
from langchain.chat_models import init_chat_model
import os

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
responces = model.invoke("why do parrots talk?")
responces.content
# Out:
# 'Parrots talk for a fascinating combination of reasons, primarily driven by their **social nature, intelligence, and their unique vocal anatomy**. It\'s not just about mimicking sounds; it\'s a complex behavior with multiple underlying motivations.\n\nHere\'s a breakdown of why parrots "talk":\n\n**1. Social Bonding and Communication:**\n\n* **Flock Communication:** In the wild, parrots are highly social animals that live in flocks. Vocalizations are crucial for maintaining contact, alerting others to danger, coordinating movement, and strengthening social bonds within the group.\n* **Mimicry as a Social Tool:** The ability to mimic sounds, including human speech, is a form of social bonding. By imitating the sounds of their flock (which, in captivity, includes humans), they are essentially trying to integrate themselves into the group and communicate on a "common ground." They learn the "language" of their social circle.\n\n**2. Intelligence and Cognitive Abilities:**\n\n* **Learnin
# ...

# %%
#chat google generative ai method

from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")
responces = model.invoke("Why do parrots talk?")
responces.content
# Out:
# 'Parrots talk primarily for two reasons: **social interaction and mimicry.**\n\nHere\'s a breakdown of why they do it:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Communication is vital for their survival and social cohesion. They use a variety of vocalizations to:\n    * **Maintain contact:** Call out to each other to stay together, especially when flying or foraging.\n    * **Alert to danger:** Warn others of predators.\n    * **Establish dominance and social hierarchy:** Vocalizations can play a role in these dynamics.\n    * **Strengthen bonds:** Engage in social calling with their flock mates.\n* **Mimicking as a Social Tool:** In the wild, parrots often mimic the calls of other parrots in their flock. This helps them blend in, identify members, and learn the "dialect" of their specific group. When a parrot is kept as a pet, it often views its human family as its flock. Mimicking h
# ...

# %% [markdown]
# ### groq model integration

# %%
from langchain.chat_models import init_chat_model
import os

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model=init_chat_model("groq:llama-3.3-70b-versatile")
responces = model.invoke("why do parrots talk? ")
responces.content
# Out:
# 'Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? There are several theories:\n\n1. **Communication and Social Bonding**: In the wild, parrots use vocalizations to communicate with each other, forming strong social bonds within their flocks. They may learn to mimic human speech as a way to bond with their human caregivers, much like they would with other parrots.\n2. **Imitation and Learning**: Parrots are intelligent birds, and they have a natural tendency to imitate sounds they hear. By mimicking human speech, they may be learning and exercising their vocal abilities, which can help them develop their own communication skills.\n3. **Attention and Interaction**: Parrots may talk to get attention from their human caregivers. They may learn that speaking or mimicking human speech gets a reaction, such as praise, treats, or playtime.\n4. **Contextual Learning**: Parrots may associate certain words or phrases with specific con
# ...

# %%
from google.genai import chats
# chat groq
from langchain_groq import ChatGroq
model = ChatGroq(model = "llama-3.3-70b-versatile")
responces = model.invoke("do dogs have a language?")
responces.content
# Out:
# 'While dogs do not possess a language in the same way humans do, they do communicate with each other and with humans through a variety of vocalizations, body language, and other behaviors. Here are some fascinating aspects of canine communication:\n\n1. **Vocalizations**: Dogs use various sounds to convey emotions, needs, and intentions, such as:\n\t* Barking: alerting, excitement, or warning\n\t* Whining: anxiety, need, or attention-seeking\n\t* Growling: warning, fear, or defensiveness\n\t* Howling: long-distance communication, social bonding, or emotional expression\n2. **Body Language**: Dogs use body postures, facial expressions, and tail language to convey information, such as:\n\t* Ear positions: relaxed, alert, or fearful\n\t* Tail wagging: excitement, friendliness, or anxiety\n\t* Posture: confidence, submission, or aggression\n\t* Facial expressions: happy, fearful, or relaxed\n3. **Scent Marking**: Dogs use scent to communicate with each other, marking their territory, and
# ...

# %% [markdown]
# # streaming and batch

# %% [markdown]
# Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
responces = model.invoke("do dogs have a language?")
responces.content
# Out:
# 'While dogs do not possess a language in the classical sense, like humans do, they do communicate with each other and with humans through a variety of vocalizations, body language, and behavioral cues. This canine communication system is often referred to as "dog language" or "canine communication."\n\nDogs use a range of signals to convey information, including:\n\n1. **Vocalizations**: Dogs bark, whine, growl, howl, and make other sounds to express emotions, needs, and intentions. Each vocalization can have a distinct meaning, such as:\n\t* Barking: alerting, excitement, or warning\n\t* Whining: anxiety, need, or attention-seeking\n\t* Growling: threat, fear, or defensiveness\n2. **Body Language**: Dogs use postures, facial expressions, and tail positions to convey information, such as:\n\t* Ears forward: interest, excitement, or alertness\n\t* Ears back: fear, submission, or anxiety\n\t* Tail wagging: excitement, friendliness, or enthusiasm\n\t* Tail tucked: fear, submission, or i
# ...

# %% [markdown]
# ### google gemini chat integration

# %%
from langchain.chat_models import init_chat_model
import os

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
responces = model.invoke("why do parrots talk?")
# Out:
# 'Parrots talk for a fascinating combination of reasons, primarily driven by their **intelligence, social nature, and their ability to mimic sounds.** It\'s not about understanding human language in the way we do, but rather a complex form of communication and social bonding.\n\nHere\'s a breakdown of the main reasons:\n\n**1. Mimicry and Vocal Learning:**\n\n*   **Highly Developed Vocal Apparatus:** Parrots have a specialized vocal organ called the **syrinx**, which is more complex than that of many other birds. This allows them to produce a wide range of sounds, including those that closely resemble human speech, other animal sounds, and environmental noises.\n*   **Innate Ability to Learn Sounds:** Parrots are **vocal learners**, meaning they are genetically predisposed to learn and reproduce sounds from their environment. This is a crucial survival trait in the wild, as it allows them to learn the calls of their flock members, potential threats, and even food sources.\n*   **"Prac
# ...

# %%
# dispaying the stream 
for chunk in model.stream("why do parrots talk?"):
    print(chunk.text)
# Out:
# Parrots talk
#  for a fascinating combination of reasons, rooted in their biology, social nature, and cognitive
#  abilities. It's not just mimicry; it's a complex form of communication and social bonding. Here's a breakdown of the key factors:
#
# **1. Social Bonding and Group Cohesion:**
#
# * **Highly Social Animals:** Par
# rots are incredibly social creatures in the wild. They live in flocks, and communication is vital for their survival. Talking, or vocalizing, helps them stay connected, warn each other of danger, locate food sources, and maintain social bonds within
#  the group.
# * **Mimicry as a Social Tool:** In their natural environment, parrots often mimic the calls of other birds in their flock. This shared vocal repertoire strengthens their group identity and allows for efficient communication. Pet parrots often
#  extend this to mimicking human sounds because we become their "flock."
#
# **2. Intelligence and Cognitive Abilities:**
#
# ...

# %%
# dispaying the stream 
for chunk in model.stream("why do we need langchain?"):
    print(chunk.text,
    end="|", 
    flush=True
    )
# Out:
# Langchain is a powerful framework| designed to **simplify and accelerate the development of applications powered by large language models (LL|Ms)**. While you *can* build LLM applications without Langchain, it offers significant advantages that make it an almost indispensable tool for anyone serious about this field.
#
# Here's a breakdown of why we need Langchain:
#
# **|1. Orchestration and Integration of LLM Components:**
#
# LLM applications are rarely just a single API call. They often involve:
#
# *   **Multiple LLM calls:** Breaking down complex tasks into smaller, manageable prompts.
# *   **Data| retrieval:** Fetching relevant information from databases, documents, or the web to inform LLM responses.
# *   **Tool usage:** Allowing LLMs to interact with external tools like search engines, calculators, or APIs.
# *   **Memory:**| Maintaining context across conversations to enable coherent dialogue.
# ...

# %% [markdown]
# ### batch

# %% [markdown]
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responces = model.batch([
    "why do birds fly?",
    "why do hummans talk?",
    "what is batch in langchain"
    ]
)
for responce in responces:
    print(responce)
# Out:
# content="Birds fly for a variety of crucial reasons, all of which contribute to their survival and reproduction. Here are the primary motivations:\n\n**1. Finding Food:**\n\n*   **Access to wider food sources:** Flight allows birds to cover large distances to find abundant food sources, whether it's insects, seeds, fruits, nectar, fish, or other prey. They can migrate to areas with seasonal food availability.\n*   **Escaping competition:** By flying to different locations, birds can avoid direct competition with other individuals or species for limited food resources.\n*   **Hunting and foraging efficiency:** Many birds, like raptors, use flight for aerial hunting, spotting prey from high above. Others use it to quickly access food in trees or on the ground.\n\n**2. Escaping Predators:**\n\n*   **Rapid evasion:** Flight is their primary defense mechanism. When threatened, birds can take to the air instantly, making them incredibly difficult for terrestrial predators to catch.\n*   **
# ...

# %%
responces = model.batch([
    "why do birds fly?",
    "why do hummans talk?",
    "what is batch in langchain"
    ],
    config={
        # limit to 5 parallal calls
        "max_concurrency" : 5,
    } 
)
for responce in responces:
    print(responce)
# Out:
# content="Birds fly for a variety of crucial reasons, all tied to their survival and success as a species. It's not just one single purpose, but a combination of advantages that flight provides. Here are the primary reasons why birds fly:\n\n**1. Foraging and Finding Food:**\n\n*   **Access to diverse food sources:** Flight allows birds to travel vast distances to find abundant food sources that might be scarce in one location. This includes insects, fruits, seeds, nectar, fish, and even other animals.\n*   **Efficient hunting:** Many birds of prey use flight to spot and then dive upon their prey from above, giving them a significant advantage.\n*   **Reaching inaccessible food:** Some food sources are only reachable by flying, such as insects on high branches or fruits on tall trees.\n\n**2. Escaping Predators:**\n\n*   **Rapid evasion:** Flight is the most effective way for birds to escape ground-based predators. They can quickly take to the air, leaving pursuing animals behind.\n* 
# ...
