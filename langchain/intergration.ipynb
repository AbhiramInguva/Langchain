# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Load API keys from the .env file in the root folder
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
print(os.environ["OPENAI_API_KEY"][:20])
# Out:
# sk-uvwxijklmnop1234u

# %%
from openai import models
from langchain.chat_models import init_chat_model
#init chat model used to initalize any chat model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x121b94150>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x121b94450>, root_client=<openai.OpenAI object at 0x1218c3850>, root_async_client=<openai.AsyncOpenAI object at 0x121b94250>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('*******
# ...

# %%
responces = model.invoke("Hello how are you?")
responces
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 responces = model.invoke("Hello how are you?")
#       2 responces
#
# File ~/Code/PYTHON/agentic/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
# ...

# %%
responces.content
# Out:
# "Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?"

# %% [markdown]
# ### google gemini model

# %%
from langchain.chat_models import init_chat_model
import os

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
responces = model.invoke("why do parrots talk?")
responces.content
# Out:
# 'Parrots talk for a fascinating combination of reasons, rooted in their biology, social nature, and cognitive abilities. It\'s not just mimicry, though that\'s a big part of it. Here\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in flocks. In the wild, they use a variety of vocalizations to communicate with each other. This includes:\n    * **Contact Calls:** To stay in touch with their flock members, especially when foraging or flying.\n    * **Alarm Calls:** To warn of danger.\n    * **Greeting Calls:** To acknowledge each other.\n    * **Social Calls:** To maintain group cohesion and reinforce social bonds.\n* **Learning Vocalizations:** Young parrots learn the specific calls and songs of their flock members. This is crucial for their survival and integration into the group.\n\n**2. Mimicry and Vocal Learning:**\n\n* **Exceptional Mimics:** Parrots are renowned for their ability
# ...
